// %% [markdown]
// # Simple example

// %%
%useLatestDescriptors
%use develocity-api-kotlin(version=2024.1.1)
%use coroutines(v=1.7.1)

val api = DevelocityApi.newInstance()

// %%
buildsApi.getBuilds(since = 0, maxBuilds = 1)
